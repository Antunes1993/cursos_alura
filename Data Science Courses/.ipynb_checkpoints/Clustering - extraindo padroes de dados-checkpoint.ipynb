# %%
import pandas as pd 
data_path = "Data\\Clustering - extraindo padroes de dados\\CC GENERAL.csv"
data = pd.read_csv(data_path)
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %% [markdown]
# # 1. Data Treatment

# %%
data = pd.read_csv(data_path)
data.drop(columns=["CUST_ID", "TENURE"], inplace=True)

for item in ["CUST_ID", "TENURE"]:
    print(f"{item} - {item in data.columns}")
# Out:
# CUST_ID - False
# TENURE - False

# %%
missing = data.isna().sum()
missing
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# dtype: int64

# %%
data.fillna(data.median(), inplace=True)
missing = data.isna().sum()
missing
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# dtype: int64

# %% [markdown]
# # 2. Normalização de Dados

# %%
from sklearn.preprocessing import Normalizer 
values = Normalizer().fit_transform(data.values)
print(values)
# Out:
# [[3.93555441e-02 7.87271593e-04 9.17958473e-02 ... 1.94178127e-01
#   1.34239194e-01 0.00000000e+00]
#  [2.93875903e-01 8.34231560e-05 0.00000000e+00 ... 3.76516684e-01
#   9.84037959e-02 2.03923046e-05]
#  [3.10798149e-01 1.24560965e-04 9.63068011e-02 ... 7.74852335e-02
#   7.81351982e-02 0.00000000e+00]
#  ...
#  [2.27733092e-02 8.11060955e-04 1.40540698e-01 ... 7.90986945e-02
#   8.02156174e-02 2.43318384e-04]
#  [2.65257948e-02 1.64255731e-03 0.00000000e+00 ... 1.03579625e-01
#   1.09898221e-01 4.92767391e-04]
#  [1.86406219e-01 3.33426837e-04 5.46778061e-01 ... 3.15915455e-02
#   4.41568390e-02 0.00000000e+00]]

# %% [markdown]
# # 3. K-Means

# %%
from sklearn.cluster import KMeans 
kmeans = KMeans(n_clusters=5, n_init=10, max_iter=300) #n_init - parametro que força o valor retornado ser igual. 
y_pred = kmeans.fit_predict(values)

# %% [markdown]
# # 4. Métricas de Validação
#
# ## 4.1 Externas
# Precisamos ter os labels. Como nao temos labels, usamos as internas que são independentes de labels.
#
# ## 4.2. Internas
#
# Critérios de validação:
#
# * Compactação - Quão próximos estão os pontos em um mesmo cluster.
# * Separação - Diz o quao bem separados estão os pontos em clusters diferentes.
#
# ## 4.3. Coeficiente de Silhouette
#
# ![image.png](attachment:image.png)
#
# a = distancia média entre um ponto específico do meu cluster e todos os outros pontos do mesmo cluster.
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# Obtendo a média das distancias temos o valor de a
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# Calculando agora o valor de b
#
# ![image.png](attachment:image.png)
#
# b = distância média entre o ponto e todos os outros pontos do cluster mais próximo. Queremos esta distância a maior possível.
